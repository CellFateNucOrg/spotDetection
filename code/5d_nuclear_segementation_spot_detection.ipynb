# %% [markdown]
# # Nuclear segmentation with emerin ring and spot detection
#
# Scripts to detect nuclei from 5d images (t,c,z,y,x) where channel 0 is green spots and channel 1 is red emerin rings.
# Mostly based on scripts from Lucien Hinderling, with some modifications and cleanup by Jennifer Semple.
#
# Nuclear segmentation carried out with Cellpose.
# Spot detection carried out with pytrack.
#
# **Inputs**:
#
# raw_input_path and denoised_input_path for directories containing raw and denoised images and output_path where results will be put. raw_input_path is used to create a dataframe with paths to images and the following
# columns:
#
# *filename	date	experiment	strain	protein	id  raw_filepath    denoised_filepath*
#
# example line:
#
# *20240915_1268_E_bean_15um	20240915	3d	1268	DPY27	DPY27_3d_20240915_1268_E_bean_15um	/mnt/external.data/MeisterLab/Dario/Imaging/DP...	/mnt/external.data/MeisterLab/Dario/Imaging/DP...*
#
# the id column is used to name images in the output_path directories
#
# **Outputs**:
#
# segmentation masks (.tif files) in output_path/segmentation/
#
# distance masks (.tif files) in output_path/edt/
#
# nuclear measurements (.csv files) in output_path/nuclei/
#
# intensity measurements for nuclei with arrays of intensity/distance from middle slice of each nuclear mask (.pkl files) in as well as other nuclear measurments and data are in output_path/dist/
#
# qc plots of segmentation on original image (segmentation_XXX.pdf), individual masked nuclei (cropped_nuclei_XXX.pdf) in output_path/qc/
#
# spot detection (.csv files, doesn't work very well) in output_path/spots/ with some qc in output_path/qc/spots*.pdf and spotGMM*.pdf
#
# ### Setting you might need to change
#
# raw_input_path - should point to directory where the nd2 images are '/mnt/external.data/MeisterLab/Dario/SDC1/1273/20241108_hs'.
# Scripts assume the denoised images are one level down in N2V_sdc1_dpy27_mSG_emr1_mCh/denoised folder.
# Scripts assume that the directory above the raw_input drive contains strain name, and the directory above that contains protein name.
#
# output_path - create a directory for the analysis. results will be stored in a protein/strain/date structure same as in the raw_input_path.
#
# Make sure file paths end with  '/'
#
# If you are not working on the server, but rather locally on a mac with izbkingston mounted as an external drive, you need to change 'server = True' to False (currently this only works for mac externally mounted drives).
#
# Set the channels for nuclear stain (nucChannel) and for spots (spotChannel) [currently 0 and 1 respectively]

# %%
import napari
import torch
from skimage.measure import regionprops_table, regionprops
from skimage.color import label2rgb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import trackpy as tp
import cellpose
from cellpose import models
import edt
import glob
import os
import tqdm
from matplotlib_scalebar.scalebar import ScaleBar
import gc
import seaborn as sns
from sklearn.mixture import GaussianMixture
from bioio import BioImage
import bioio_nd2
import bioio_tifffile
from bioio.writers import OmeTiffWriter
import scipy.stats as stats
from scipy import optimize


#anisotropy = (3,1,1) # Relative scale of (Z,X,Y) axes now calculated inside scripts

nucChannel = 0 # red emerin rings
spotChannel = 1 # green spots
server = True # is the script running on the server or mounted on mac

def macMount(path): # tansforms server path to path for izbkingston mounted on mac
    newpath = path.replace('/mnt/','/Volumes/')
    return newpath



# in lucien's original scripts:
# channel 0 is green spots
# channel 1 is red emerin

pd.set_option('display.max_columns', None)

# %%
# on server
#raw_input_path = '/mnt/external.data/MeisterLab/Dario/Imaging/DPY27/1268/20241107_hs/'
#raw_input_path = '/mnt/external.data/MeisterLab/Dario/Imaging/SDC1/1273/20241108_hs/'
#raw_input_path = '/mnt/external.data/MeisterLab/Dario/Imaging/DPY27/1268/20241010_tl/'
#raw_input_path = '/mnt/external.data/MeisterLab/Dario/SDC1/1273/20241010_tl/'
raw_input_path = '/mnt/external.data/MeisterLab/Dario/SDC1/1273/20240813_3d/'
# extract identifying directories from raw_input_path
protein_strain_date = '/'.join(os.path.normpath(raw_input_path).split(os.sep)[-3:])
output_path = '/mnt/external.data/MeisterLab/jsemple/lhinder/segmentation_Dario/'+protein_strain_date+'/'


if(not server):
    raw_input_path = macMount(raw_input_path)
    output_path = macMount(output_path)

denoised_input_path = raw_input_path+'N2V_sdc1_dpy27_mSG_emr1_mCh/denoised/'


if not os.path.exists(output_path+"/qc"):
    os.makedirs(output_path+"/qc")

if not os.path.exists(output_path+"/segmentation"):
    os.makedirs(output_path+"/segmentation")

if not os.path.exists(output_path+"/edt"):
    os.makedirs(output_path+"/edt")

if not os.path.exists(output_path+"/spots"):
    os.makedirs(output_path+"/spots")

if not os.path.exists(output_path+"/nuclei"):
    os.makedirs(output_path+"/nuclei")

if not os.path.exists(output_path+"/dist"):
    os.makedirs(output_path+"/dist")


raw_file_name_pattern = "/*.nd2"
denoised_file_name_pattern = "/*_n2v.tif"
raw_filepaths = sorted(glob.glob(raw_input_path + raw_file_name_pattern,recursive=True))
raw_filepaths = [filepath for filepath in raw_filepaths if '_bad.nd2' not in filepath]

print(f"Found {len(raw_filepaths)} *.nd2 files.")
# Out:
# Found 44 *.nd2 files.

# %% [markdown]
# Generate data frame of file paths with metadata

# %%
if(server): #only save if running on server
    df = pd.DataFrame()
    df['filename'] = [os.path.basename(filepath)[:-4] for filepath in raw_filepaths]
    tmpdate = [os.path.normpath(filepath).split(os.sep)[-2] for filepath in raw_filepaths]
    df['date'] = pd.Series([exp.split('_')[0] for exp in tmpdate])
    df['experiment'] = pd.Series([exp.split('_')[1] for exp in tmpdate])
    df['strain'] = [os.path.normpath(filepath).split(os.sep)[-3] for filepath in raw_filepaths]
    df['protein'] = [os.path.normpath(filepath).split(os.sep)[-4] for filepath in raw_filepaths]
    df['id'] = df['protein'] + '_' + df['experiment'] + '_' + df['filename'] 
    df['raw_filepath'] = raw_filepaths
    df['denoised_filepath'] = [denoised_input_path+filename+'_n2v.tif' for filename in df['filename']]
    df.to_csv(output_path+'fileList.csv',index=False)
else:
    df=pd.read_csv(output_path+'fileList.csv')
    for i in range(len(df)):
        df.at[i,'raw_filepath'] = macMount(df.at[i,'raw_filepath'])
        df.at[i,'denoised_filepath'] = macMount(df.at[i,'denoised_filepath'])


df
# Out:
#                          filename      date experiment strain protein  \
# 0    20240813_1273_E_bean_15um_01  20240813         3d   1273    SDC1
# 1    20240813_1273_E_bean_15um_02  20240813         3d   1273    SDC1
# 2    20240813_1273_E_bean_15um_03  20240813         3d   1273    SDC1
# 3    20240813_1273_E_bean_15um_04  20240813         3d   1273    SDC1
# 4    20240813_1273_E_bean_15um_05  20240813         3d   1273    SDC1
# 5    20240813_1273_E_bean_15um_06  20240813         3d   1273    SDC1
# 6   20240813_1273_E_early_15um_01  20240813         3d   1273    SDC1
# 7   20240813_1273_E_early_15um_02  20240813         3d   1273    SDC1
# 8   20240813_1273_E_early_15um_03  20240813         3d   1273    SDC1
# 9   20240813_1273_E_early_15um_04  20240813         3d   1273    SDC1
# 10  20240813_1273_E_early_15um_05  20240813         3d   1273    SDC1
# 11  20240813_1273_E_early_15um_06  20240813         3d   1273    SDC1
# 12  20240813_1273_E_early_15um_07  20240813         3d   1273    SDC1
# 13  20240813_1273_E_early_15um_08  20240813         3d   1273    SDC1
# 14  20240813_1273_E_early_15um_09  20240813         3d   1273    SDC1
# 15  20240813_1273_E_early_15um_10  20240813         3d   1273    SDC1
# 16  20240813_1273_E_early_15um_11  20240813         3d   1273    SDC1
# 17  20240813_1273_E_early_15um_12  20240813         3d   1273    SDC1
# 18  20240813_1273_E_early_15um_13  20240813         3d   1273    SDC1
# 19   20240813_1273_E_late_15um_01  20240813         3d   1273    SDC1
# 20   20240813_1273_E_late_15um_02  20240813         3d   1273    SDC1
# 21   20240813_1273_E_late_15um_03  20240813         3d   1273    SDC1
# 22   20240813_1273_E_late_15um_04  20240813         3d   1273    SDC1
# 23   20240813_1273_E_late_15um_05  20240813         3d   1273    SDC1
# 24   20240813_1273_E_late_15um_06  20240813         3d   1273    SDC1
# 25   20240813_1273_E_late_15um_07  20240813         3d   1273    SDC1
# 26   20240813_1273_E_late_15um_08  20240813         3d   1273    SDC1
# 27   20240813_1273_E_late_15um_09  20240813         3d   1273    SDC1
# 28   20240813_1273_E_late_15um_10  20240813         3d   1273    SDC1
# 29   20240813_1273_E_late_15um_11  20240813         3d   1273    SDC1
# 30   20240813_1273_E_late_15um_12  20240813         3d   1273    SDC1
# 31    20240813_1273_E_mid_15um_01  20240813         3d   1273    SDC1
# 32    20240813_1273_E_mid_15um_02  20240813         3d   1273    SDC1
# 33    20240813_1273_E_mid_15um_03  20240813         3d   1273    SDC1
# 34    20240813_1273_E_mid_15um_04  20240813         3d   1273    SDC1
# 35    20240813_1273_E_mid_15um_05  20240813         3d   1273    SDC1
# 36    20240813_1273_E_mid_15um_06  20240813         3d   1273    SDC1
# 37    20240813_1273_E_mid_15um_07  20240813         3d   1273    SDC1
# 38    20240813_1273_E_mid_15um_08  20240813         3d   1273    SDC1
# 39    20240813_1273_E_mid_15um_09  20240813         3d   1273    SDC1
# 40    20240813_1273_E_mid_15um_10  20240813         3d   1273    SDC1
# 41    20240813_1273_E_mid_15um_11  20240813         3d   1273    SDC1
# 42    20240813_1273_E_mid_15um_12  20240813         3d   1273    SDC1
# 43    20240813_1273_E_mid_15um_13  20240813         3d   1273    SDC1
#
#                                        id  \
# 0    SDC1_3d_20240813_1273_E_bean_15um_01
# 1    SDC1_3d_20240813_1273_E_bean_15um_02
# 2    SDC1_3d_20240813_1273_E_bean_15um_03
# 3    SDC1_3d_20240813_1273_E_bean_15um_04
# 4    SDC1_3d_20240813_1273_E_bean_15um_05
# 5    SDC1_3d_20240813_1273_E_bean_15um_06
# 6   SDC1_3d_20240813_1273_E_early_15um_01
# 7   SDC1_3d_20240813_1273_E_early_15um_02
# 8   SDC1_3d_20240813_1273_E_early_15um_03
# 9   SDC1_3d_20240813_1273_E_early_15um_04
# 10  SDC1_3d_20240813_1273_E_early_15um_05
# 11  SDC1_3d_20240813_1273_E_early_15um_06
# 12  SDC1_3d_20240813_1273_E_early_15um_07
# 13  SDC1_3d_20240813_1273_E_early_15um_08
# 14  SDC1_3d_20240813_1273_E_early_15um_09
# 15  SDC1_3d_20240813_1273_E_early_15um_10
# 16  SDC1_3d_20240813_1273_E_early_15um_11
# 17  SDC1_3d_20240813_1273_E_early_15um_12
# 18  SDC1_3d_20240813_1273_E_early_15um_13
# 19   SDC1_3d_20240813_1273_E_late_15um_01
# 20   SDC1_3d_20240813_1273_E_late_15um_02
# 21   SDC1_3d_20240813_1273_E_late_15um_03
# 22   SDC1_3d_20240813_1273_E_late_15um_04
# 23   SDC1_3d_20240813_1273_E_late_15um_05
# 24   SDC1_3d_20240813_1273_E_late_15um_06
# 25   SDC1_3d_20240813_1273_E_late_15um_07
# 26   SDC1_3d_20240813_1273_E_late_15um_08
# 27   SDC1_3d_20240813_1273_E_late_15um_09
# 28   SDC1_3d_20240813_1273_E_late_15um_10
# 29   SDC1_3d_20240813_1273_E_late_15um_11
# 30   SDC1_3d_20240813_1273_E_late_15um_12
# 31    SDC1_3d_20240813_1273_E_mid_15um_01
# 32    SDC1_3d_20240813_1273_E_mid_15um_02
# 33    SDC1_3d_20240813_1273_E_mid_15um_03
# 34    SDC1_3d_20240813_1273_E_mid_15um_04
# 35    SDC1_3d_20240813_1273_E_mid_15um_05
# 36    SDC1_3d_20240813_1273_E_mid_15um_06
# 37    SDC1_3d_20240813_1273_E_mid_15um_07
# 38    SDC1_3d_20240813_1273_E_mid_15um_08
# 39    SDC1_3d_20240813_1273_E_mid_15um_09
# 40    SDC1_3d_20240813_1273_E_mid_15um_10
# 41    SDC1_3d_20240813_1273_E_mid_15um_11
# 42    SDC1_3d_20240813_1273_E_mid_15um_12
# 43    SDC1_3d_20240813_1273_E_mid_15um_13
#
#                                          raw_filepath  \
# 0   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 1   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 2   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 3   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 4   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 5   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 6   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 7   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 8   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 9   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 10  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 11  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 12  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 13  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 14  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 15  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 16  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 17  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 18  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 19  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 20  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 21  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 22  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 23  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 24  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 25  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 26  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 27  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 28  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 29  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 30  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 31  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 32  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 33  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 34  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 35  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 36  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 37  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 38  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 39  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 40  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 41  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 42  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 43  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
#
#                                     denoised_filepath
# 0   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 1   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 2   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 3   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 4   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 5   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 6   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 7   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 8   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 9   /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 10  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 11  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 12  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 13  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 14  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 15  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 16  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 17  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 18  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 19  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 20  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 21  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 22  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 23  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 24  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 25  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 26  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 27  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 28  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 29  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 30  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 31  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 32  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 33  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 34  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 35  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 36  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 37  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 38  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 39  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 40  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 41  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 42  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...
# 43  /mnt/external.data/MeisterLab/Dario/SDC1/1273/...

# %% [markdown]
# Load model

# %%
torch.cuda.device(0)
model_path='/mnt/external.data/MeisterLab/lhinder/segmentation_3d_anja/code/worms_1000epochs_v0'
if(not server):
    model_path = macMount(model_path)

if torch.cuda.is_available():
    print("GPU is available")
    model = models.CellposeModel(pretrained_model=model_path, gpu=True, device =torch.device('cuda:0'))
else:
    print("Only CPU is available")
    model = models.CellposeModel(pretrained_model=model_path, gpu=False)


# no gpu, from local machine with izbkingston mounted 
#model = models.CellposeModel(pretrained_model='/Volumes/external.data/MeisterLab/lhinder/segmentation_3d_anja/code/worms_1000epochs_v0')
# Out:
# GPU is available
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/cellpose/resnet_torch.py:276: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(filename, map_location=device)

# %% [markdown]
# ## Functions for nuclear segmentation and qc

# %%
# Disable do_3D, there is a bug. 2D and stitching with overlap works much better.
# Takes around 7min for the whole image on the macbook
def segment_nuclei(img, model):
    ''' use pytorch cellpose model to segment nuclei'''
    masks,flows,styles = model.eval(img,do_3D=False,stitch_threshold=0.3,cellprob_threshold =0,diameter =36)
    return masks,flows,styles


def calc_distance_mask(masks,anisotropy):
    '''Calculate the distance map from the nuclei-edge towards the center of nucleus'''
    masks_edt = edt.edt(masks,anisotropy = anisotropy)
    return masks_edt




def plot_qc_nuclei_crop(df, index, df_region_props, img, t=0, display = False, seed=1):
    '''Plot a cropped region of a random sample of 10 nuclei from each image'''
    nb_nuc = 10
    np.random.seed(seed)
    indices_to_sample = np.random.choice(range(len(df_region_props)),size = nb_nuc,replace = False)
    # sort indeces in descending order of area

    widths=[df_region_props['image'][i].shape[1] for i in indices_to_sample]

    fig, axs = plt.subplots(nrows = 2, ncols = nb_nuc, figsize = (15,5),dpi = 250, 
                            sharex=False, sharey=False, width_ratios=widths)
    fig.suptitle(f'Cropped nuclei {df.id.iloc[index]}', fontsize=16)

    for i,sample in enumerate(indices_to_sample):
        intensity_image = df_region_props['intensity_image'][sample][:,:,:,spotChannel] #show first spot channel
        image = df_region_props['image'][sample]
        mx = np.ma.masked_array(intensity_image,mask = ~image)
        z_height = image.shape[0] 
        axs[0,i].imshow(mx[int(z_height/2)])
        axs[0,i].spines['top'].set_visible(False)
        axs[0,i].spines['right'].set_visible(False)
        axs[0,i].spines['bottom'].set_visible(False)
        axs[0,i].spines['left'].set_visible(False)
        axs[0,i].get_xaxis().set_ticks([])
        axs[0,i].get_yaxis().set_ticks([])

    for i,sample in enumerate(indices_to_sample):
        intensity_image = df_region_props['intensity_image'][sample][:,:,:,nucChannel] #show second nuclear channel
        image = df_region_props['image'][sample]
        mx = np.ma.masked_array(intensity_image,mask = ~image)
        z_height = image.shape[0]
        axs[1,i].imshow(mx[int(z_height/2)])
        axs[1,i].spines['top'].set_visible(False)
        axs[1,i].spines['right'].set_visible(False)
        axs[1,i].spines['bottom'].set_visible(False)
        axs[1,i].spines['left'].set_visible(False)
        axs[1,i].get_xaxis().set_ticks([])
        axs[1,i].get_yaxis().set_ticks([])

        if i == nb_nuc-1:
            scalebar = ScaleBar(0.065, "um", length_fraction=1, box_alpha=0.7,color='black',location='lower right',height_fraction = 0.05,border_pad =-1)
            axs[1,i].add_artist(scalebar)

    #plt.tight_layout()
    fig.savefig(output_path + 'qc/cropped_nuclei_'+df.id.iloc[index]+'_t'+'{:02d}'.format(t)+'.pdf')
    if display == False:
        plt.close()
    else:
        plt.show()


def plot_single_nucleus_crop(df, index, df_region_props, nuc_index, img):
    '''Plot a cropped region of a particular nucleus'''

    fig, axs = plt.subplots(nrows = 1, ncols = 2, figsize = (3,1.5),dpi = 250, sharey=True)
    fig.suptitle(f'{df.id.iloc[index]}', fontsize=6)

    intensity_image = df_region_props['intensity_image'][nuc_index][:,:,:,spotChannel] #show first spot channel
    image = df_region_props['image'][nuc_index]
    mx = np.ma.masked_array(intensity_image, mask = ~image)
    z_height = image.shape[0] 
    axs[0].imshow(mx[int(z_height/2)])
    axs[0].spines['top'].set_visible(False)
    axs[0].spines['right'].set_visible(False)
    axs[0].spines['bottom'].set_visible(False)
    axs[0].spines['left'].set_visible(False)
    axs[0].get_xaxis().set_ticks([])
    axs[0].get_yaxis().set_ticks([])


    intensity_image = df_region_props['intensity_image'][nuc_index][:,:,:,nucChannel] #show second nuclear channel
    image = df_region_props['image'][nuc_index]
    mx = np.ma.masked_array(intensity_image, mask = ~image)
    z_height = image.shape[0]
    axs[1].imshow(mx[int(z_height/2)])
    axs[1].spines['top'].set_visible(False)
    axs[1].spines['right'].set_visible(False)
    axs[1].spines['bottom'].set_visible(False)
    axs[1].spines['left'].set_visible(False)
    axs[1].get_xaxis().set_ticks([])
    axs[1].get_yaxis().set_ticks([])


    scalebar = ScaleBar(0.065, "um", length_fraction=1, box_alpha=0.7,color='black',location='lower right',height_fraction = 0.05,border_pad =-1)
    axs[1].add_artist(scalebar)

    plt.show()


def plot_qc_segmentation_xyz(img, masks, index, df, t=0, display_plot=False, plotContours=False):
    '''Plot a 2x3 grid of xy, xz, yz slices of the image and the corresponding segmentation'''
    nucChannel = 0
    num_z=img.shape[1]
    num_y=img.shape[2]
    num_x=img.shape[3]
    nlabel=100

    fig = plt.figure(layout='constrained',dpi=450,figsize = (10,10))
    fig.suptitle(f'Segmentation for {df.id.iloc[index]}', fontsize=10)
    subfigs = fig.subfigures(2, 1, wspace=0.1)

    axsTop = subfigs[0].subplots(2, 3,sharex=True, sharey=True)
    #xy
    axsTop[0,0].imshow(label2rgb(masks[int(num_z*0.3),:,:],bg_label=0,bg_color=(255, 255, 255),colors=np.random.random((nlabel, 3))))
    axsTop[1,0].set_title('z='+str(int(num_z*0.3)), fontsize=8)
    axsTop[0,1].imshow(label2rgb(masks[int(num_z*0.5),:,:],bg_label=0,bg_color=(255, 255, 255),colors=np.random.random((nlabel, 3))))
    axsTop[1,1].set_title('z='+str(int(num_z*0.5)), fontsize=8)
    axsTop[0,2].imshow(label2rgb(masks[int(num_z*0.7),:,:],bg_label=0,bg_color=(255, 255, 255),colors=np.random.random((nlabel, 3))))
    axsTop[1,2].set_title('z='+str(int(num_z*0.7)), fontsize=8)

    axsTop[1,0].imshow(img[nucChannel,int(num_z*0.3),:,:],cmap = 'gray_r')
    axsTop[1,1].imshow(img[nucChannel,int(num_z*0.5),:,:],cmap = 'gray_r')
    axsTop[1,2].imshow(img[nucChannel,int(num_z*0.7),:,:],cmap = 'gray_r')

    if plotContours:
        axsTop[1,0].contour(masks[int(num_z*0.3),:,:], [0.5], linewidths=0.5, colors='r')
        axsTop[1,1].contour(masks[int(num_z*0.5),:,:], [0.5], linewidths=0.5, colors='r')
        axsTop[1,2].contour(masks[int(num_z*0.7),:,:], [0.5], linewidths=0.5, colors='r')



    for axss in axsTop:
        for ax in axss:
            #ax.set_xlim(0,num_x)
            #ax.set_ylim(0,num_y)
            ax.set_xticks([])
            ax.set_yticks([])

    axsBottom = subfigs[1].subplots(4, 3,sharex=True,sharey=True)
    #xz
    axsBottom[0,0].imshow(label2rgb(masks[:,int(num_y*0.3),:],bg_label=0,bg_color=(255, 255, 255),colors=np.random.random((nlabel, 3))))
    axsBottom[1,0].set_title('y='+str(int(num_y*0.3)), fontsize=8)
    axsBottom[0,1].imshow(label2rgb(masks[:,int(num_y*0.5),:],bg_label=0,bg_color=(255, 255, 255),colors=np.random.random((nlabel, 3))))
    axsBottom[1,1].set_title('y='+str(int(num_y*0.5)), fontsize=8)
    axsBottom[0,2].imshow(label2rgb(masks[:,int(num_y*0.7),:],bg_label=0,bg_color=(255, 255, 255),colors=np.random.random((nlabel, 3))))
    axsBottom[1,2].set_title('y='+str(int(num_y*0.7)), fontsize=8)

    axsBottom[1,0].imshow(img[nucChannel,:,int(num_y*0.3),:],cmap = 'gray_r')
    axsBottom[1,1].imshow(img[nucChannel,:,int(num_y*0.5),:],cmap = 'gray_r')
    axsBottom[1,2].imshow(img[nucChannel,:,int(num_y*0.7),:],cmap = 'gray_r')

    if plotContours:
        axsBottom[1,0].contour(masks[:,int(num_y*0.3),:], [0.5], linewidths=0.5, colors='r')
        axsBottom[1,1].contour(masks[:,int(num_y*0.5),:], [0.5], linewidths=0.5, colors='r')
        axsBottom[1,2].contour(masks[:,int(num_y*0.7),:], [0.5], linewidths=0.5, colors='r')


    #yz
    axsBottom[2,0].imshow(label2rgb(masks[:,:,int(num_x*0.3)],bg_label=0,bg_color=(255, 255, 255),colors=np.random.random((nlabel, 3))))
    axsBottom[3,0].set_title('x='+str(int(num_x*0.3)), fontsize=8)
    axsBottom[2,1].imshow(label2rgb(masks[:,:,int(num_x*0.5)],bg_label=0,bg_color=(255, 255, 255),colors=np.random.random((nlabel, 3))))
    axsBottom[3,1].set_title('x='+str(int(num_x*0.5)), fontsize=8)
    axsBottom[2,2].imshow(label2rgb(masks[:,:,int(num_x*0.7)],bg_label=0,bg_color=(255, 255, 255),colors=np.random.random((nlabel, 3))))
    axsBottom[3,2].set_title('x='+str(int(num_x*0.7)), fontsize=8)

    axsBottom[3,0].imshow(img[nucChannel,:,:,int(num_x*0.3)],cmap = 'gray_r')
    axsBottom[3,1].imshow(img[nucChannel,:,:,int(num_x*0.5)],cmap = 'gray_r')
    axsBottom[3,2].imshow(img[nucChannel,:,:,int(num_x*0.7)],cmap = 'gray_r')

    if plotContours:
        axsBottom[3,0].contour(masks[:,:,int(num_x*0.3)], [0.5], linewidths=0.5, colors='r')
        axsBottom[3,1].contour(masks[:,:,int(num_x*0.5)], [0.5], linewidths=0.5, colors='r')
        axsBottom[3,2].contour(masks[:,:,int(num_x*0.7)], [0.5], linewidths=0.5, colors='r')

    for axss in axsBottom:
        for ax in axss:
            #ax.set_ylim(0,num_z)
            ax.set_xticks([])
            ax.set_yticks([])

    plt.tight_layout()
    if display_plot:
        plt.show()
    else:
        fig.savefig(output_path + 'qc/segmentation_'+df.id.iloc[index]+'_t'+'{:02d}'.format(t)+'.png')
        plt.close()

# %%
## Run the segmentation script on all images (reserve more than 24GB!)
# this produces segmentation, segmentation_qc and edt files
def run_nuclear_segmentation(indices, df, rerun=False):
    '''Run the segmentation on all images in the dataframe'''
    for index in tqdm.tqdm(indices):
        if rerun or not os.path.exists(output_path+'edt/'+df.id.iloc[index]+'_t0.tif'):
            # get anisotropy from raw image metadata
            img_5d = BioImage(df.raw_filepath.iloc[index], reader=bioio_nd2.Reader)
            ZvX = np.round(img_5d.physical_pixel_sizes.Z/img_5d.physical_pixel_sizes.X,0)
            anisotropy = (ZvX,1,1)
            # Load the denoised data
            img_5d = BioImage(df.denoised_filepath.iloc[index], reader=bioio_tifffile.Reader)
            for t in range(img_5d.dims.T):
                img = img_5d.get_image_data("CZYX", T=t)

                # Segment nuclei 
                masks,flows,styles = segment_nuclei(img[nucChannel,:,:,:],model) # Run the segmentation
                plot_qc_segmentation_xyz(img,masks,index, df, t, display_plot = False)                         # Create qc plot
                OmeTiffWriter.save(masks, output_path+'segmentation/'+df.id.iloc[index]+'_t'+'{:02d}'.format(t)+'.tif')

                del flows
                del styles
                gc.collect()
                
                # Calculate edt 
                masks_edt = calc_distance_mask(masks,anisotropy)
                OmeTiffWriter.save(masks_edt, output_path+'edt/'+df.id.iloc[index]+'_t'+'{:02d}'.format(t)+'.tif')

                del masks
                del masks_edt
                gc.collect()
                continue

# %%
## read images
## crop the nuclei slices
## calculate EDT transform
## for each nuclei loop over all distances (1:40) and take mean
## array of distance/intensity measurements are taken only for middle slice of mask (?)

## nucleus_id | nucleus volume | [1:20] mean intensities | group | ...


def run_dist_analysis(indices,df):
    '''Run the distance analysis on all images in the dataframe'''
    for index in tqdm.tqdm(indices):
        
        df_nuclei = pd.DataFrame()
        print(df.iloc[index].raw_filepath)

        img_5d = BioImage(df.raw_filepath.iloc[index], reader=bioio_nd2.Reader)
        # calculate anisotropy from raw image metadata
        ZvX = np.round(img_5d.physical_pixel_sizes.Z/img_5d.physical_pixel_sizes.X,0)

        for t in range(img_5d.dims.T):
            img = img_5d.get_image_data("ZYXC", T=t)

            masks = BioImage(output_path+'segmentation/'+df.id.iloc[index]+'_t'+'{:02d}'.format(t)+'.tif', reader=bioio_tifffile.Reader)
            masks = masks.get_image_data("ZYX", T=0, C=0)
            
            df_region_props = regionprops_table(masks,img, properties = ['label', 'area','centroid','MajorAxisLength','solidity','image','intensity_image'])
            df_region_props = pd.DataFrame(df_region_props)

            if len(df_region_props)>=10:
                plot_qc_nuclei_crop(df, index, df_region_props, img, t=t, display = False) 

            for i in range(len(df_region_props)):
                df_nuclei_temp = pd.DataFrame()

                intensity_image_spots = df_region_props['intensity_image'][i][:,:,:,spotChannel] #show spot channel
                intensity_image_nuclei = df_region_props['intensity_image'][i][:,:,:,nucChannel] #show nuclear ring channel

                image = df_region_props['image'][i]  # binary 3d mask

                # Extract the intensity per distance
                mx_spots = np.ma.masked_array(intensity_image_spots, mask = ~image) # 3d masked spot channel
                mx_nuclei = np.ma.masked_array(intensity_image_nuclei,mask = ~image) # 3d masked nuclear ring channel
                mx_mask = np.ma.masked_array(image,mask = ~image)  # 3d masked binary mask

                z_height = image.shape[0]

                slice_spots = mx_spots[int(z_height/2)]
                slice_nuclei = mx_nuclei[int(z_height/2)]
                slice_mask = mx_mask[int(z_height/2)]

                slice_mask_edt = edt.edt(slice_mask)
                slice_mask_edt = np.ma.masked_array(slice_mask_edt, mask = ~(slice_mask_edt>0)) 

                results = regionprops_table(slice_mask_edt.astype('int'),slice_nuclei,properties=['label','intensity_mean'])
                intensity_dist_nuclei = results['intensity_mean']

                results = regionprops_table(slice_mask_edt.astype('int'),slice_spots,properties=['label','intensity_mean'])
                intensity_dist_spots = results['intensity_mean']

                dist = results['label']

                df_nuclei_temp['label']  = [df_region_props.label.iloc[i]]
                df_nuclei_temp['bb_dimZ']  = [mx_spots.shape[0]]
                df_nuclei_temp['bb_dimY']  = [mx_spots.shape[1]]
                df_nuclei_temp['bb_dimX']  = [mx_spots.shape[2]]
                df_nuclei_temp['centroid_z'] = df_region_props['centroid-0'][i]
                df_nuclei_temp['centroid_y'] = df_region_props['centroid-1'][i]
                df_nuclei_temp['centroid_x'] = df_region_props['centroid-2'][i]
                df_nuclei_temp['major_axis_length'] = df_region_props['MajorAxisLength'][i]
                df_nuclei_temp['solidity'] = df_region_props['solidity'][i]
                df_nuclei_temp['mean'] = [np.ma.mean(mx_spots)]
                df_nuclei_temp['median'] = [np.ma.median(mx_spots)]
                df_nuclei_temp['std']=  [np.ma.std(mx_spots)]
                df_nuclei_temp['sum']= [np.ma.sum(mx_spots)]
                df_nuclei_temp['variance']= [np.ma.var(mx_spots)]
                df_nuclei_temp['max'] = [np.ma.max(mx_spots)]
                df_nuclei_temp['min'] = [np.ma.min(mx_spots)]
                df_nuclei_temp['volume'] = [np.sum(np.invert(mx_spots.mask))]
                df_nuclei_temp['id'] = [df.id.iloc[index]]
                df_nuclei_temp['timepoint'] = [t]
                df_nuclei_temp['intensity_dist_nuclei'] = [intensity_dist_nuclei]  # this is the emerin ring channel intensity on central slice
                df_nuclei_temp['intensity_dist_spots'] = [intensity_dist_spots] # this is the spot channel but not actual detected spots
                df_nuclei_temp['intensity_dist'] = [dist]  # this is the distance from the edge of the nucleus
                df_nuclei_temp['zproj_spots'] = [np.max(intensity_image_spots[:,:,:], axis = 0)]
                df_nuclei_temp['zproj_nuclei'] = [np.max(intensity_image_nuclei[:,:,:], axis = 0)]
                df_nuclei_temp['anisotropy'] = [ZvX]

                df_nuclei = pd.concat([df_nuclei,df_nuclei_temp])

        # save as pickle because has array stored in Dataframe
        df_nuclei.to_pickle(output_path+'dist/'+df.id.iloc[index]+'.pkl') # Back up the DF for this FOV

        # save with metadata as csv for simple viewing 
        df_nuclei_for_csv = pd.merge(df_nuclei,df,on='id',how='left')
        df_nuclei_for_csv.drop( columns = [ 'intensity_dist_nuclei','intensity_dist_spots','intensity_dist' ], axis=1, inplace=True)
        df_nuclei_for_csv.to_csv(output_path+'nuclei/'+df.id.iloc[index]+'.csv', index=False)

# %% [markdown]
# ## Functions for spot detection and qc

# %%
def find_spots(img, diameter=(9,5,5), separation=(3,2,2)):
    '''Find protein clusters of a certain size. Method is very sensitive, be sure to filter the spots afterwards using the signal value.
    Input: img -> 3D array from C0 containing
    Output: pandas.df containing data with all the detected spots.
            x,y,z: centroid of spot in image coordinates (px space)
            mass: total integrated brightness of the blob
            size: radius of gyration of its Gaussian-like profile
            ecc: eccentricity
            raw_mass: integrated brightness in raw_image '''

    #features = tp.locate(img, diameter=diameter, engine='numba',minmass = 10,percentile = 0.95,max_iterations=3,preprocess = True) #check 
    features = tp.locate(img[:,:,:], diameter, minmass=None, maxsize=None, separation=separation, noise_size=1, smoothing_size=None, threshold=None, invert=False, percentile=95, topn=None, preprocess=True, max_iterations=3, filter_before=None, filter_after=None, characterize=True, engine='numba')
    return features


def extract_spot_features(features, masks, masks_edt):
    '''For each spot get the label of the corresponding nucleus and distance to its envelope.'''

    for feature in features.iterrows():
        index = feature[0]
        x = round(feature[1].x)
        y = round(feature[1].y)
        z = round(feature[1].z)
        dist = masks_edt[z,y,x]
        label = masks[z,y,x]
        features.loc[index,'dist'] = dist
        features.loc[index,'label'] = int(label)
        
    return features
#features = extract_spot_features(features,masks,masks_edt)

def filter_spots(features, measure = 'signal', signal_strength = 0.1):
    '''Remove all spots that lie outside of a nucleus (or where nucleus is not detected.
       Remove all spots with signal<signal_strength'''
    features_filt = features[(features['dist']>0)&(features[measure]>signal_strength)]
    return features_filt

# %%
def plot_qc_spot_detection(index, df, df_features, img, t=0, display_plot = False,
                            measure = 'signal', thresholds = [1 ,2.5, 5, 10]):
    '''Plot the spot detection for a given image using several thresholds for the signal strength (shown on Z projections)'''
    z_projection = np.max(img[:,:,:], axis = 0)
    #masks_z_projection = np.max(masks[:,:,:], axis = 0)
    features_filt_01 = filter_spots(df_features, measure = measure, signal_strength = thresholds[0])
    features_filt_02 = filter_spots(df_features, measure = measure, signal_strength = thresholds[1])
    features_filt_03 = filter_spots(df_features, measure = measure, signal_strength =  thresholds[2])
    features_filt_04 = filter_spots(df_features, measure = measure, signal_strength = thresholds[3])


    fig, axs = plt.subplots(2,2,figsize = (6,7),dpi= 450)

    for axss in axs:
        for ax in axss:
            ax.set_xticks([])
            ax.set_yticks([])


    axs[0,0].imshow(z_projection, cmap = 'gray_r')
    axs[0,0].scatter(features_filt_01[['x']],features_filt_01[['y']], s = 0.3, linewidths=0.1, alpha = 1, edgecolors = 'red', facecolors='none')
    #axs[0,0].contour(masks_z_projection, [0.5], linewidths=0.5, colors='green')
    axs[0,0].set_title(f'{measure}>{thresholds[0]} (n={len(features_filt_01)})', fontsize=8,y=-0.01)

    axs[0,1].imshow(z_projection, cmap = 'gray_r')
    axs[0,1].scatter(features_filt_02[['x']],features_filt_02[['y']], s = 0.3, linewidths=0.1, alpha = 1, edgecolors = 'red', facecolors='none')
    #axs[0,1].contour(masks_z_projection, [0.5], linewidths=0.5, colors='green')
    axs[0,1].set_title(f'{measure}>{thresholds[1]} (n={len(features_filt_02)})', fontsize=8,y=-0.01)

    axs[1,0].imshow(z_projection, cmap = 'gray_r')
    axs[1,0].scatter(features_filt_03[['x']],features_filt_03[['y']], s = 0.3, linewidths=0.11, alpha = 1, edgecolors = 'red', facecolors='none')
    #axs[1,0].contour(masks_z_projection, [0.5], linewidths=0.5, colors='green')
    axs[1,0].set_title(f'{measure}>{thresholds[2]} (n={len(features_filt_03)})', fontsize=8,y=-0.01)

    axs[1,1].imshow(z_projection, cmap = 'gray_r')
    axs[1,1].scatter(features_filt_04[['x']],features_filt_04[['y']], s = 0.3, linewidths=0.1, alpha = 1, edgecolors = 'red', facecolors='none')
    #axs[1,1].contour(masks_z_projection, [0.5], linewidths=0.5, colors='green')
    axs[1,1].set_title(f'{measure}>{thresholds[3]} (n={len(features_filt_04)})', fontsize=8,y=-0.01)

    plt.tight_layout()
    fig.suptitle(f'Spot detection for {df.filename.iloc[index]}', fontsize=10)
    #xs[0,0].imshow(masks[10,:,:]>0,cmap = 'gray_r')

    if display_plot:
        plt.show()
    else:
        fig.savefig(output_path + 'qc/spots_'+df.id.iloc[index]+'_t'+'{:02d}'.format(t)+'.png')
        plt.close()

# %%
def plot_qc_spot_threshold(index, df, df_spots, t=0, display_plot=False, measure='signal'):
    ''' Fits mixed gaussian model to find threshold of spot mass

    Parameters:
    index (int): Index of image whose spots should be analysed
    df (pd.DataFrame): Data frame with list of image ids

    Returns:
    Saves a spotThreshold__.pdf for each image with a histogram, model fit and 
    threshold and returns image id, number of spots and the estimated threshold
    '''
    #df_spots = pd.read_csv(output_path+'spots/'+df.id.iloc[index]+'.csv')
    #df_spots = df_spots[df_spots['timepoint']==t]
    x = np.array(df_spots[measure]).reshape(-1,1)
    gm =GaussianMixture(n_components=2,random_state=0).fit(x)
    mu1=gm.means_[0]
    mu2=gm.means_[1]
    sigma1=np.sqrt(gm.covariances_[0])
    sigma2=np.sqrt(gm.covariances_[1])
    threshold=np.round(float(mu1+3*sigma1),2)

    x_fit = np.linspace(0,max(x),100)
    y_fit = gm.score_samples(x_fit)

    plt.figure(figsize=(10,6))
    g = sns.histplot(data=df_spots,x=measure,stat='density',label="Data")
    plt.plot(x_fit,np.exp(y_fit),color='red',lw=1,ls='-',label="Fitted bimodal distribution")
    plt.axvline(mu1,0,1,color='red',lw=0.5,ls="--",label="Mean first gaussian")
    plt.axvline(threshold,0,1,color='red',lw=2,ls="-",label="Threshold (mean1+3*SD1)")
    plt.axvline(mu2,0,1,color='red',lw=0.5,ls=":",label="Mean second gaussian")
    plt.annotate('Threshold='+str(threshold),xy=(0.4,0.9),xycoords='axes fraction')
    plt.title('Distribution of spot '+measure+' as mixture of two gaussians')
    plt.xlabel(measure)
    plt.legend()

    if display_plot:
        plt.show()
    else:
        plt.savefig(output_path + 'qc/spotGMM_'+df.id.iloc[index]+'_t'+'{:02d}'.format(t)+'.pdf')
        plt.close()
    id=df.id.iloc[index]
    num_spot=len(df_spots)
    return(num_spot, threshold)

# %%
def run_spot_analysis(indices, df, useRaw=True, diameter=(7,9,9), separation=(5,7,7), qc_thresholds=[1,2.5,5,10]):
    '''Finds spots and estimates threshold'''
    ids = list()
    num_spots = list()
    thresholds = list()
    timepoints = list()
    for index in tqdm.tqdm(indices):
        # Load the data
        # with ND2Reader(df.filepath.iloc[index]) as images:
        #     images.bundle_axes = ['z','x','y','c']
        #     img = images[0]
        df_features = pd.DataFrame()
        if useRaw:
            img_5d = BioImage(df.raw_filepath.iloc[index], reader=bioio_nd2.Reader)
        else:
            img_5d = BioImage(df.denoised_filepath.iloc[index], reader=bioio_tifffile.Reader)
        
        for t in range(img_5d.dims.T):
            img = img_5d.get_image_data("ZYX", T=t, C=spotChannel)

            # get masks for this timepoint
            masks = BioImage(output_path+'segmentation/'+df.id.iloc[index]+'_t'+'{:02d}'.format(t)+'.tif', reader=bioio_tifffile.Reader)
            masks = masks.get_image_data("ZYX", T=0, C=0)

            masks_edt = BioImage(output_path+'edt/'+df.id.iloc[index]+'_t'+'{:02d}'.format(t)+'.tif', reader=bioio_tifffile.Reader)
            masks_edt = masks_edt.get_image_data("ZYX", T=0, C=0)

            # Find the spots (location given in image coordinate system )
            df_spots = find_spots(img[:,:,:],diameter = diameter,separation = separation)
            df_features_temp = extract_spot_features(df_spots, masks, masks_edt)    # For all the spots calculate the features

            
            df_features_temp = filter_spots(df_features_temp, measure='signal', signal_strength = 0.0001)
            if len(df_features_temp) == 0:
                print('EMPTY DF!!')
                print(df.filename.iloc[index])
                print('INDEX:' + str(index))
            else:
                print('found spots:' + str(len(df_features_temp)))


            df_features_temp.loc[:,'id'] = df.id.iloc[index]
            df_features_temp.loc[:,'timepoint'] = t

            #plot spots detected at different thresholds
            plot_qc_spot_detection(index, df, df_features_temp, img, t=t, display_plot = False, measure = 'signal', thresholds = qc_thresholds) # Plot and save the QC of the spot detection

            # Use mixed Guassian model to separate background from true spots
            num_spot, threshold = plot_qc_spot_threshold(index, df, df_features_temp, t=t, display_plot = False, measure = 'signal')
            ids.append(df.id.iloc[index])
            timepoints.append(t)
            num_spots.append(num_spot)
            thresholds.append(threshold)

            # append to main table
            df_features = pd.concat([df_features,df_features_temp])

        # output spot table for each raw image
        df_features.to_csv(output_path+'spots/'+df.id.iloc[index]+'.csv') # Back up the DF for this FOV

    # output table of spot numbers and thresholds for all images
    df_thresholds = pd.DataFrame(data = {'id': ids, 'timepoint': timepoints, 'num_spots': num_spots, 'threshold': thresholds })
    df_thresholds.to_csv(output_path+'spotGMMthresholds.csv',index=False)
    return df_thresholds


def replot_spots_with_thresholds(indices, df, useRaw=True, qc_thresholds=[1,2.5,5,10]):
    '''Replots the spot qc images without recalculating the spots, so one can try different qc thresholds'''
    for index in tqdm.tqdm(indices):
        # Load the data
        # with ND2Reader(df.filepath.iloc[index]) as images:
        #     images.bundle_axes = ['z','x','y','c']
        #     img = images[0]
        if useRaw:
            img_5d = BioImage(df.raw_filepath.iloc[index], reader=bioio_nd2.Reader)
        else:
            img_5d = BioImage(df.denoised_filepath.iloc[index], reader=bioio_tifffile.Reader)
        
        df_features =  pd.read_csv(output_path+'spots/'+df.id.iloc[index]+'.csv') # get spots data

        for t in range(img_5d.dims.T):
            img = img_5d.get_image_data("ZYX", T=t, C=spotChannel)

            # Get masks
            masks = BioImage(output_path+'segmentation/'+df.id.iloc[index]+'_t'+'{:02d}'.format(t)+'.tif', reader=bioio_tifffile.Reader)
            masks = masks.get_image_data("ZYX", T=0, C=0)

            df_features_temp = df_features[df_features['timepoint'] == t]
            
            #plot spots detected at different thresholds
            plot_qc_spot_detection(index, df, df_features_temp, img, t=t, display_plot = False, measure = 'signal', thresholds = qc_thresholds) # Plot and save the QC of the spot detection

# %% [markdown]
# ## Functions to gather results into single file

# %%
def collect_nuclear_segmentation_data(indices, df, suffix = 'v001'):
    '''Collects nuclear intensity and intensity vs distance data for all nuclei in the dataset'''
    df_nuclei = pd.DataFrame()
    for index in tqdm.tqdm(indices):
        df_tmp = pd.read_csv(output_path+'nuclei/'+df.id.iloc[index]+'.csv')
        df_nuclei = pd.concat([df_nuclei,df_tmp])
    df_nuclei.to_csv(output_path+'nuclei_analysis_'+suffix+'.csv',index=False)



def collect_nuclear_distance_data(indices, df, suffix = 'v001'):
    '''Collects nuclear intensity and intensity vs distance data for all nuclei in the dataset'''
    df_dist = pd.DataFrame()
    for index in tqdm.tqdm(indices):
        df_tmp = pd.read_pickle(output_path+'dist/'+df.id.iloc[index]+'.pkl')
        df_dist = pd.concat([df_dist,df_tmp])
    df_dist.to_pickle(output_path+'dist_analysis_'+suffix+'.pkl')


def collect_spot_data(indices, df, suffix = 'v001'):
    '''Collects spot data for all images'''
    df_spots = pd.DataFrame()
    for index in tqdm.tqdm(indices):
        df_tmp = pd.read_csv(output_path+'spots/'+df.id.iloc[index]+'.csv')
        df_spots = pd.concat([df_spots,df_tmp])
    df_spots.to_csv(output_path+'spots_analysis_'+suffix+'.csv',index=False)

# %% [markdown]
# ## Running the analysis for nuclear segmentation

# %%
# run analysis to segment nuclei
indices=range(0,len(df))
#indices=[0]

run_nuclear_segmentation(indices, df, rerun=True) 

run_dist_analysis(indices, df)

collect_nuclear_segmentation_data(indices, df, suffix = 'v001')
collect_nuclear_distance_data(indices, df, suffix = 'v001')
# Out:
# 100%|██████████| 75/75 [00:00<00:00, 113.74it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.002615467218696099..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.022970371124707345..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006725025509496274..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010237010332194596..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.002219513159981923..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0224802057074025..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0026681291110228766..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011495586456650608..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.012863803527497497..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 533.38it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0003467724026263719..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.007412161228464886..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006024128734621881..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00779008115642732..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.013555636667731408..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006458894869205478..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.008210271550456505..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.003445686504489842..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0011888792048346808..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 564.87it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0007760777073214653..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0013872416326566883..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.007301095996130713..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.003007236218352527..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.009953156151588982..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0162109773844612..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0036501827055729352..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0042816919707413525..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.008824554269919349..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 578.09it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [4.001358372318631e-05..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006526479208310176..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.005165610331420378..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03256495643449919..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00017569965143982014..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.013409829447383337..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.015615724706192435..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00562169289324721..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.015065258453317854..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 492.47it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0003503528794518429..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.004174899799721965..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0016369878049194986..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02037262184895594..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0051913904564433455..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0029339974829599713..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00840752439428416..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00786853926536224..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.009134244476061482..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 777.09it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0049081514762120415..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0008174165550479673..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0019313896121982976..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.04916234540229292..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.003327984288252872..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0045065250325243555..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01552802696782396..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.013327224506693103..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.014358525054291027..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 606.29it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.001796836059443696..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0012310831401911582..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0066701331431208155..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.032772199625832665..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02887550474968059..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.020996438008543783..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.10916063851188673..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011743865359979955..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.018687544997824657..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 581.53it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0009031661435425775..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02579467964371651..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.019395309970194452..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011868754107339341..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.005499936947930495..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.041132547466156466..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.12871211894441725..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.022587621126314184..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.007234023703567627..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 817.93it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01578894405949871..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03331762689643636..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.005580130370220537..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.06406982465868549..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03335872629960257..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03882112746309008..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.023579243054166588..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02047856399542325..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01014180792126651..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 603.27it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010428044360097255..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.014781182850440944..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.025003635754605513..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.008338115968847148..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.10457408074077224..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0026216610537523888..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.042181860790210246..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.003485017442219185..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02133262590946816..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 555.33it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.040010565454489444..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03476345484127952..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.003671488066679607..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.16516532288201613..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.13800011541077284..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.025747343285672186..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.024340692115968787..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.29546212710117314..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.008438081627780925..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 604.35it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.07050672320293128..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.033267032207348834..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.021214113422800218..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02094676967520226..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.12423491006821419..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.07751775218686252..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.04198493205139897..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.015280462006729834..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.07491603766095689..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 789.83it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.005540257823454686..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.004062869285718307..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0074441264900082516..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0023855481949955903..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03459091881470189..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01669490311330224..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.06570157994909653..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.008618419891113893..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.001168064172612171..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 677.51it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.020065296556151635..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0034864116616902807..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00038466215691634886..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.009520039618986953..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0164123161228783..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.04924485697649661..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.016699721573770865..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0475026648401784..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.17620991262963281..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 291.14it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010259519699975628..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.06384252709038374..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0280839796971869..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.36713519543535755..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.29548053101017313..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.32082863908962456..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.23373895345798656..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.4527807095173464..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.060968778242594834..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 484.00it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.018132268430901877..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006938389292279079..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0023046992657672627..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010694620427655122..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006088917773494185..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.034259943453541664..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006768125617037324..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00029264900873227084..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0794885853237266..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 692.26it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00488478611201737..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.012977943558767469..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0024450553852014556..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.032638041375743776..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.012446794403768724..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010517999067667816..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0038105463782820426..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00876244677027771..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01249072437114851..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 516.42it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03274158014053219..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.007823348779520511..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006351135575230704..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.18458849954947543..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.10481368239218036..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.09791212117765358..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006928493404430025..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.023744648756685582..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.07925822840549035..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 779.40it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.021665080290280136..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.009207511490415765..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0039348591989455395..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.032654586841209254..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011852162295707735..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01795559879144304..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.16823722920903383..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.05506006393414409..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0024435231814401437..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 495.27it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0003151901717248773..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.008750488074660612..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00319865296088484..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0014517822442760009..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0006603409273464589..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0011225415160259766..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0007564467851747247..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.09588153930754839..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02373842080601718..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 528.25it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0022062372199229685..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006707973497535491..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011442947457329766..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.003908259601336783..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02381797640562633..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0006352526945080372..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.020803772128592746..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0036445882140576646..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.004430217883125254..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 594.86it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.002582241157561449..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0007094595962532368..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.029268527162538582..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01103194944772301..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03447023705935803..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.004860574480331947..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010760789192792442..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01086534445320153..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.031987096864102504..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
#  50%|█████     | 22/44 [11:09<10:49, 29.51s/it]WARNING: no mask pixels found
# 100%|██████████| 75/75 [00:00<00:00, 570.50it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.005909233188519658..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0088410687169026..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0014216945898437583..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.05396673274711883..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.020043059251809714..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03992982766777342..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011098523645858616..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0011048372073794166..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.07373749866516477..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 496.37it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0012971469138072234..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006032152798774115..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.008735203806162772..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0016894397147676488..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.009355840309496766..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.003041806990215168..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0032318179620343113..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.005771077147797898..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0037504999491519975..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 809.43it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.007435419215666705..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.014888126886235642..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.007457392726061274..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.020973778221406225..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0033207684949406735..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.04516994355548187..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.009567991286083988..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011578575476778874..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03238091042760727..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 511.83it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006316238546806963..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0010895551177428908..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01024953495923786..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.016948815024049324..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.018141603157767583..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006752667169293902..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01237456627998934..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0024059507095015586..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0210213954694477..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 631.19it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.026819650272185913..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.007168720447350729..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00501515202178493..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010856720509360929..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0066351090265983625..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00522276742075356..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.004577125349579103..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.002929391173157714..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0014225103244132065..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 437.37it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.003817426697995785..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.005137236608606099..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0049486749365924565..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.008371102152714416..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0008472134123082009..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.03462091032265513..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.002399011737893808..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.002286740954770994..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0038887106764933232..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 489.13it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0010443889830994424..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0021528716619345634..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0041493845849363..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00032054628165101295..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010766660330314926..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02177783739309791..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0060211428813979895..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0012191597640928142..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00012601339119933108..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 381.46it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00022229884412949819..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0006669043541404074..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.018340212187664906..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.029401258525793006..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.004274827728646846..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.004022920209243996..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.011115570339281011..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.003086059638875316..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0031403518322870028..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 521.12it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.02480876782843322..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.015126954240573753..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.006465021472002563..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.01286659872800855..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.019974494562685963..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0003203441235853921..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.005479935765946409..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.005802721103080333..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0007403689580220973..255.0].
# /tmp/ipykernel_2683013/3847159726.py:187: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# 100%|██████████| 75/75 [00:00<00:00, 487.46it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.017299955150518964..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0002865731006012062..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.010587329447855343..255.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.00019804909551801586..255.0].
# ...
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026029484  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 34  Error-roundoff 4.7e-14  _one-merge 3.3e-13
#   _near-inside 1.7e-12  Visible-distance 9.4e-14  U-max-coplanar 9.4e-14
#   Width-outside 1.9e-13  _wide-facet 5.7e-13  _maxoutside 3.8e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026029484  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 29  Error-roundoff 4e-14  _one-merge 2.8e-13  _near-inside 1.4e-12
#   Visible-distance 8e-14  U-max-coplanar 8e-14  Width-outside 1.6e-13
#   _wide-facet 4.8e-13  _maxoutside 3.2e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026046291  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 26  Error-roundoff 3.6e-14  _one-merge 2.5e-13
#   _near-inside 1.3e-12  Visible-distance 7.2e-14  U-max-coplanar 7.2e-14
#   Width-outside 1.4e-13  _wide-facet 4.3e-13  _maxoutside 2.9e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026046291  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 22  Error-roundoff 3.1e-14  _one-merge 2.1e-13
#   _near-inside 1.1e-12  Visible-distance 6.1e-14  U-max-coplanar 6.1e-14
#   Width-outside 1.2e-13  _wide-facet 3.7e-13  _maxoutside 2.4e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026046291  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 42  Error-roundoff 5.8e-14  _one-merge 4.1e-13  _near-inside 2e-12
#   Visible-distance 1.2e-13  U-max-coplanar 1.2e-13  Width-outside 2.3e-13
#   _wide-facet 7e-13  _maxoutside 4.7e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026046291  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 32  Error-roundoff 4.4e-14  _one-merge 3.1e-13
#   _near-inside 1.6e-12  Visible-distance 8.9e-14  U-max-coplanar 8.9e-14
#   Width-outside 1.8e-13  _wide-facet 5.3e-13  _maxoutside 3.6e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026046291  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 35  Error-roundoff 4.7e-14  _one-merge 3.3e-13
#   _near-inside 1.7e-12  Visible-distance 9.5e-14  U-max-coplanar 9.5e-14
#   Width-outside 1.9e-13  _wide-facet 5.7e-13  _maxoutside 3.8e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026046291  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 29  Error-roundoff 4e-14  _one-merge 2.8e-13  _near-inside 1.4e-12
#   Visible-distance 8e-14  U-max-coplanar 8e-14  Width-outside 1.6e-13
#   _wide-facet 4.8e-13  _maxoutside 3.2e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026046291  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 35  Error-roundoff 4.9e-14  _one-merge 3.4e-13
#   _near-inside 1.7e-12  Visible-distance 9.7e-14  U-max-coplanar 9.7e-14
#   Width-outside 1.9e-13  _wide-facet 5.8e-13  _maxoutside 3.9e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026046291  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 34  Error-roundoff 4.7e-14  _one-merge 3.3e-13
#   _near-inside 1.7e-12  Visible-distance 9.4e-14  U-max-coplanar 9.4e-14
#   Width-outside 1.9e-13  _wide-facet 5.7e-13  _maxoutside 3.8e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026046291  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 25  Error-roundoff 3.5e-14  _one-merge 2.4e-13
#   _near-inside 1.2e-12  Visible-distance 6.9e-14  U-max-coplanar 6.9e-14
#   Width-outside 1.4e-13  _wide-facet 4.2e-13  _maxoutside 2.8e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026046291  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 37  Error-roundoff 5.1e-14  _one-merge 3.6e-13
#   _near-inside 1.8e-12  Visible-distance 1e-13  U-max-coplanar 1e-13
#   Width-outside 2.1e-13  _wide-facet 6.2e-13  _maxoutside 4.1e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026046291  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 33  Error-roundoff 4.6e-14  _one-merge 3.2e-13
#   _near-inside 1.6e-12  Visible-distance 9.2e-14  U-max-coplanar 9.2e-14
#   Width-outside 1.8e-13  _wide-facet 5.5e-13  _maxoutside 3.7e-13
#
#   return convex_hull_image(self.image)
#  98%|█████████▊| 43/44 [13:16<00:18, 18.98s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# /mnt/external.data/MeisterLab/Dario/SDC1/1273/20240813_3d/20240813_1273_E_mid_15um_13.nd2
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026214361  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 37  Error-roundoff 5.1e-14  _one-merge 3.6e-13
#   _near-inside 1.8e-12  Visible-distance 1e-13  U-max-coplanar 1e-13
#   Width-outside 2.1e-13  _wide-facet 6.2e-13  _maxoutside 4.1e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:632: RuntimeWarning: divide by zero encountered in scalar divide
#   return self.area / self.area_convex
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026315203  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 35  Error-roundoff 4.9e-14  _one-merge 3.4e-13
#   _near-inside 1.7e-12  Visible-distance 9.7e-14  U-max-coplanar 9.7e-14
#   Width-outside 1.9e-13  _wide-facet 5.8e-13  _maxoutside 3.9e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026332010  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 28  Error-roundoff 3.9e-14  _one-merge 2.7e-13
#   _near-inside 1.3e-12  Visible-distance 7.7e-14  U-max-coplanar 7.7e-14
#   Width-outside 1.5e-13  _wide-facet 4.6e-13  _maxoutside 3.1e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026332010  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 42  Error-roundoff 5.8e-14  _one-merge 4.1e-13  _near-inside 2e-12
#   Visible-distance 1.2e-13  U-max-coplanar 1.2e-13  Width-outside 2.3e-13
#   _wide-facet 7e-13  _maxoutside 4.7e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026348817  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 23  Error-roundoff 3.1e-14  _one-merge 2.1e-13
#   _near-inside 1.1e-12  Visible-distance 6.1e-14  U-max-coplanar 6.1e-14
#   Width-outside 1.2e-13  _wide-facet 3.7e-13  _maxoutside 2.5e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026382431  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 32  Error-roundoff 4.4e-14  _one-merge 3.1e-13
#   _near-inside 1.6e-12  Visible-distance 8.9e-14  U-max-coplanar 8.9e-14
#   Width-outside 1.8e-13  _wide-facet 5.3e-13  _maxoutside 3.6e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026382431  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 43  Error-roundoff 6e-14  _one-merge 4.2e-13  _near-inside 2.1e-12
#   Visible-distance 1.2e-13  U-max-coplanar 1.2e-13  Width-outside 2.4e-13
#   _wide-facet 7.2e-13  _maxoutside 4.8e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026382431  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 45  Error-roundoff 6.2e-14  _one-merge 4.4e-13
#   _near-inside 2.2e-12  Visible-distance 1.2e-13  U-max-coplanar 1.2e-13
#   Width-outside 2.5e-13  _wide-facet 7.5e-13  _maxoutside 5e-13
#
#   return convex_hull_image(self.image)
# /home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/skimage/measure/_regionprops.py:433: UserWarning: Failed to get convex hull image. Returning empty image, see error message below:
# QH6013 qhull input error: input is less than 3-dimensional since all points have the same x coordinate    0
#
# While executing:  | qhull i Qt
# Options selected for Qhull 2019.1.r 2019/06/21:
#   run-id 1026399238  incidence  Qtriangulate  _pre-merge  _zero-centrum
#   _max-width 28  Error-roundoff 3.9e-14  _one-merge 2.7e-13
#   _near-inside 1.4e-12  Visible-distance 7.8e-14  U-max-coplanar 7.8e-14
#   Width-outside 1.6e-13  _wide-facet 4.7e-13  _maxoutside 3.1e-13
#
#   return convex_hull_image(self.image)
# 100%|██████████| 44/44 [13:34<00:00, 18.51s/it]
# 100%|██████████| 44/44 [00:00<00:00, 137.36it/s]
# 100%|██████████| 44/44 [00:00<00:00, 85.04it/s]

# %% [markdown]
# ## Running the analysis for spot detection
# This is currently not working well so can ignore it.

# %%
#indices=[0]
indices=range(0,len(df))

run_spot_analysis(indices, df, useRaw=True, diameter=(7,9,9), separation=(7,9,9), qc_thresholds=[1,3,6,10])
#replot_spots_with_thresholds(indices, df, useRaw=False, qc_thresholds=[10, 15, 20, 25])

collect_spot_data(indices, df, suffix = 'v001')
# Out:
#   0%|          | 0/44 [00:00<?, ?it/s]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1981
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#   2%|▏         | 1/44 [00:15<10:53, 15.19s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1754
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#   5%|▍         | 2/44 [00:27<09:22, 13.40s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1068
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#   7%|▋         | 3/44 [00:38<08:34, 12.56s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1563
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#   9%|▉         | 4/44 [00:52<08:35, 12.89s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:2255
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  11%|█▏        | 5/44 [01:05<08:33, 13.17s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1434
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  14%|█▎        | 6/44 [01:15<07:28, 11.80s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1418
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  16%|█▌        | 7/44 [01:30<08:02, 13.04s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1130
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  18%|█▊        | 8/44 [01:46<08:24, 14.02s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1609
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  20%|██        | 9/44 [01:58<07:42, 13.20s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1433
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  23%|██▎       | 10/44 [02:16<08:19, 14.69s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1420
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  25%|██▌       | 11/44 [02:35<08:49, 16.06s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1383
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  27%|██▋       | 12/44 [02:52<08:40, 16.26s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1183
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  30%|██▉       | 13/44 [03:06<08:03, 15.60s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1376
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  32%|███▏      | 14/44 [03:22<07:50, 15.67s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:634
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  34%|███▍      | 15/44 [04:03<11:21, 23.49s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1812
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  36%|███▋      | 16/44 [04:24<10:33, 22.63s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1632
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  39%|███▊      | 17/44 [04:38<09:04, 20.18s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1111
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  41%|████      | 18/44 [04:53<08:04, 18.64s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1724
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  43%|████▎     | 19/44 [05:04<06:47, 16.31s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1678
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  45%|████▌     | 20/44 [05:20<06:26, 16.12s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:891
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  48%|████▊     | 21/44 [05:34<05:56, 15.49s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1964
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  50%|█████     | 22/44 [05:48<05:32, 15.09s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1506
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  52%|█████▏    | 23/44 [06:03<05:15, 15.01s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:2107
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  55%|█████▍    | 24/44 [06:22<05:24, 16.24s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1496
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  57%|█████▋    | 25/44 [06:34<04:44, 14.97s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:2296
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  59%|█████▉    | 26/44 [06:52<04:47, 15.98s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1536
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  61%|██████▏   | 27/44 [07:03<04:06, 14.53s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:2647
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  64%|██████▎   | 28/44 [07:22<04:13, 15.85s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1616
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  66%|██████▌   | 29/44 [07:37<03:51, 15.42s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:2579
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  68%|██████▊   | 30/44 [07:55<03:45, 16.10s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1788
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  70%|███████   | 31/44 [08:07<03:16, 15.12s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:2077
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  73%|███████▎  | 32/44 [08:25<03:11, 15.96s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1561
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  75%|███████▌  | 33/44 [08:40<02:50, 15.54s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:2067
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  77%|███████▋  | 34/44 [08:55<02:34, 15.40s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1873
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  80%|███████▉  | 35/44 [09:10<02:18, 15.43s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1933
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  82%|████████▏ | 36/44 [09:23<01:56, 14.61s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1627
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  84%|████████▍ | 37/44 [09:38<01:43, 14.74s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:2684
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  86%|████████▋ | 38/44 [09:56<01:33, 15.65s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:2703
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  89%|████████▊ | 39/44 [10:11<01:16, 15.39s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1800
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  91%|█████████ | 40/44 [10:23<00:58, 14.60s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:2259
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  93%|█████████▎| 41/44 [10:35<00:40, 13.64s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1122
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  95%|█████████▌| 42/44 [10:48<00:26, 13.35s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:2220
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
#  98%|█████████▊| 43/44 [10:59<00:12, 12.93s/it]/home/jsemple/miniforge3/envs/lhcellpose1/lib/python3.10/site-packages/dask/tokenize.py:242: UserWarning: ND2File file not closed before garbage collection. Please use `with ND2File(...):` context or call `.close()`.
#   mod.loads(out, buffers=buffers)
# found spots:1674
# /tmp/ipykernel_2683013/2810972793.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'id'] = df.id.iloc[index]
# /tmp/ipykernel_2683013/2810972793.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_features_temp.loc[:,'timepoint'] = t
# /tmp/ipykernel_2683013/507995495.py:20: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   threshold=np.round(float(mu1+3*sigma1),2)
# 100%|██████████| 44/44 [11:10<00:00, 15.23s/it]
# 100%|██████████| 44/44 [00:00<00:00, 98.26it/s]
